# %%
import random 
def gamefosforos(fosforos):
    jogador1=input("Pressione 'm' se quiser jogar primeiro ou pressione 'c' se quiser jogar em segundo")
    if jogador1=='m':
        while(fosforos>=1): 
            jogada1=int(input("Quantos fósforos quer tirar?"))
            if jogada1>4 or jogada1<=0:
                print("ERRO!")
                break
            else:
                entrejogada=fosforos-jogada1
                jogadac=5-jogada1
                fosforos=fosforos-(jogada1+jogadac)
                prinzzt("sobraram",fosforos,"fósforos")
                if (fosforos==1):
                    print("PERDEU!")
                    break
    if jogador1=='c':
        while(fosforos>=1):
            jogadac=random.randint(1,4)
            fosforos=fosforos-jogadac
            print("sobraram",fosforos, "fósforos")
            while fosforos>1:
                jogada1=int(input("Quantos fósforos quer tirar?"))
                if jogada1>=1 and jogada1<=4:    
                    fosforos=fosforos-jogadac
                    print("sobraram", fosforos, "fósforos")   
                    if fosforos==1:
                        print("Jogador ganha!Parabéns!")
                    if fosforos==2:
                        jogadac=1
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos")
                        print("O Jogador perdeu!")
                    if fosforos==3:
                        jogadac=2
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos")
                        print("O Jogador perdeu!")
                    if fosforos==4:
                        jogadac=3
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                        print("O Jogador perdeu!")
                    if fosforos==5:
                        jogadac=4
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                        print("O Jogador perdeu!")
                    if fosforos==6:
                        jogadac=random.randint(1,4)
                        fosforos=fosforos-jogadac
                        print("sobraram",fosforos, "fósforos!")
                    if fosforos==7:
                        jogadac=1
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==8:
                        jogadac=2
                        fosforos=fosforos-jogadac
                        print("sobraram",fosforos, "fósforos!")
                    if fosforos==9:
                        jogadac=3
                        fosforos=fosforos-jogadac
                        print("sobraram",fosforos, "fósforos!")
                    if fosforos==10:
                        jogadac=4
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==11:
                        jogadac=random.randint(1,4)
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==12:
                        jogadac=1
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==13:
                        jogadac=2
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==14:
                        jogadac=3
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==15:
                        jogadac=4
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==16:
                        jogadac=random.randint(1,4)
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==17:
                        jogadac=1
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==18:
                        jogadac=2
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==19:
                        jogadac=3
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                    if fosforos==20:
                        jogadac=4
                        fosforos=fosforos-jogadac
                        print("sobraram", fosforos, "fósforos!")
                if jogada1<1 or jogada1>4:
                    print("Erro!")
        print("Fim de jogo. Jogador perdeu")         
        
gamefosforos(21)
